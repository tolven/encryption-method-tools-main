# %%
def Diffie_Hellmann(p,g,a,b):
    print("A alice_key = g^a mod p = ", g**a % p)
    print("B bob_key = g^b mod p = ", g**b % p)
    ak = g**a % p
    bk = g**b % p
    print("\n")
    print("bob erhählt alice key:")
    print("SessionSchlüsselalice_key^b mod p = ", ak ** b % p)
    
    print("\n")

# %%
Diffie_Hellmann(7,3,5,3)
# Out:
# A alice_key = g^a mod p =  5
# B bob_key = g^b mod p =  6
#
#
# bob erhählt alice key:
# SessionSchlüsselalice_key^b mod p =  6
